# %%
import os
import requests
import json
import pandas as pd
from datetime import datetime
import time

# %%
API_KEY = os.environ.get("CRYPTO_API_KEY")
CRYPTO_CURRENCY = "BTC"
LOCAL_CURRENCY = "EUR"
BATCH_SIZE = 10
API_ENDPOINT = "histohour"

# %% [markdown]
# # 1. API Investigation

# %%
request = requests.get(f"https://min-api.cryptocompare.com/data/v2/{API_ENDPOINT}?fsym={CRYPTO_CURRENCY}&tsym={LOCAL_CURRENCY}&limit={BATCH_SIZE}&{API_KEY}")
# request.content --> return type is actually bytes and not a json, but containing a json object
# bytes can be converted back to json using loads from json library
rep = json.loads(request.content)

# %%
rep
# Out:
# {'Response': 'Success',
#  'Message': '',
#  'HasWarning': False,
#  'Type': 100,
#  'RateLimit': {},
#  'Data': {'Aggregated': False,
#   'TimeFrom': 1746507600,
#   'TimeTo': 1746543600,
#   'Data': [{'time': 1746507600,
#     'high': 83548.34,
#     'low': 83330.57,
#     'open': 83512.31,
#     'volumefrom': 19.15,
#     'volumeto': 1597467.91,
#     'close': 83363.69,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746511200,
#     'high': 83467.87,
#     'low': 83360.52,
#     'open': 83363.69,
#     'volumefrom': 22.32,
#     'volumeto': 1861414.42,
#     'close': 83432.99,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746514800,
#     'high': 83492.04,
#     'low': 83196.8,
#     'open': 83432.99,
#     'volumefrom': 38.95,
#     'volumeto': 3246153.83,
#     'close': 83257.66,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746518400,
#     'high': 83313.76,
#     'low': 82918.39,
#     'open': 83257.66,
#     'volumefrom': 91.08,
#     'volumeto': 7566983.96,
#     'close': 83313.76,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746522000,
#     'high': 83357.11,
#     'low': 83145.04,
#     'open': 83313.76,
#     'volumefrom': 38.54,
#     'volumeto': 3207371.58,
#     'close': 83332,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746525600,
#     'high': 83370.61,
#     'low': 82941.25,
#     'open': 83332,
#     'volumefrom': 60.62,
#     'volumeto': 5041409.93,
#     'close': 82975.02,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746529200,
#     'high': 83076.83,
#     'low': 82756.62,
#     'open': 82975.02,
#     'volumefrom': 52.45,
#     'volumeto': 4350319.08,
#     'close': 82857.12,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746532800,
#     'high': 82959.73,
#     'low': 82785.46,
#     'open': 82857.12,
#     'volumefrom': 46.62,
#     'volumeto': 3864315.77,
#     'close': 82870.26,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746536400,
#     'high': 82879.31,
#     'low': 82281.16,
#     'open': 82870.26,
#     'volumefrom': 139.24,
#     'volumeto': 11503479.44,
#     'close': 82490.53,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746540000,
#     'high': 83433.43,
#     'low': 82481.4,
#     'open': 82490.53,
#     'volumefrom': 119.36,
#     'volumeto': 9911093.23,
#     'close': 83033.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1746543600,
#     'high': 83494.68,
#     'low': 82998.59,
#     'open': 83033.24,
#     'volumefrom': 39.08,
#     'volumeto': 3253497.93,
#     'close': 83491.17,
#     'conversionType': 'direct',
#     'conversionSymbol': ''}]}}

# %%
data = rep['Data']['Data']
# Convert list of dictionnaries into a DataFrame
df = pd.json_normalize(data)

# %%
df
# Out:
#           time      high       low      open  volumefrom     volumeto  \
# 0   1746507600  83548.34  83330.57  83512.31       19.15   1597467.91
# 1   1746511200  83467.87  83360.52  83363.69       22.32   1861414.42
# 2   1746514800  83492.04  83196.80  83432.99       38.95   3246153.83
# 3   1746518400  83313.76  82918.39  83257.66       91.08   7566983.96
# 4   1746522000  83357.11  83145.04  83313.76       38.54   3207371.58
# 5   1746525600  83370.61  82941.25  83332.00       60.62   5041409.93
# 6   1746529200  83076.83  82756.62  82975.02       52.45   4350319.08
# 7   1746532800  82959.73  82785.46  82857.12       46.62   3864315.77
# 8   1746536400  82879.31  82281.16  82870.26      139.24  11503479.44
# 9   1746540000  83433.43  82481.40  82490.53      119.36   9911093.23
# 10  1746543600  83494.68  82998.59  83033.24       39.08   3253497.93
#
#        close conversionType conversionSymbol
# 0   83363.69         direct
# 1   83432.99         direct
# 2   83257.66         direct
# 3   83313.76         direct
# 4   83332.00         direct
# 5   82975.02         direct
# 6   82857.12         direct
# 7   82870.26         direct
# 8   82490.53         direct
# 9   83033.24         direct
# 10  83491.17         direct

# %% [markdown]
# As you can see, we do not have dates and hours but integers instead.
# More precisely, they are timestamps which makes compatibility between systems, storage and calculation easier.
# However, if we want to expose our database with these data to business users, we have to convert timestamp back to "understandable" dates, so we provide meaningful data.

# %%
df["time"] = df["time"].apply(lambda time: datetime.fromtimestamp(time))
df.drop(columns=["conversionType", "conversionSymbol"], inplace=True)
df
# Out:
#                   time      high       low      open  volumefrom     volumeto  \
# 0  2025-05-06 07:00:00  83548.34  83330.57  83512.31       19.15   1597467.91
# 1  2025-05-06 08:00:00  83467.87  83360.52  83363.69       22.32   1861414.42
# 2  2025-05-06 09:00:00  83492.04  83196.80  83432.99       38.95   3246153.83
# 3  2025-05-06 10:00:00  83313.76  82918.39  83257.66       91.08   7566983.96
# 4  2025-05-06 11:00:00  83357.11  83145.04  83313.76       38.54   3207371.58
# 5  2025-05-06 12:00:00  83370.61  82941.25  83332.00       60.62   5041409.93
# 6  2025-05-06 13:00:00  83076.83  82756.62  82975.02       52.45   4350319.08
# 7  2025-05-06 14:00:00  82959.73  82785.46  82857.12       46.62   3864315.77
# 8  2025-05-06 15:00:00  82879.31  82281.16  82870.26      139.24  11503479.44
# 9  2025-05-06 16:00:00  83433.43  82481.40  82490.53      119.36   9911093.23
# 10 2025-05-06 17:00:00  83494.68  82998.59  83033.24       39.08   3253497.93
#
#        close
# 0   83363.69
# 1   83432.99
# 2   83257.66
# 3   83313.76
# 4   83332.00
# 5   82975.02
# 6   82857.12
# 7   82870.26
# 8   82490.53
# 9   83033.24
# 10  83491.17

# %% [markdown]
# As you can see, the amount of data fetched is limited to the batch size defined at the beginning.
# We could increase it to 2000 (max authorized by CoinDesk) but we would still miss data.
# As advised by CoinDesk, we need then to retrieve data by batch and iterate using the earliest date available in the metadata (i.e TimeFrom)

# %% [markdown]
# # 2. ETL Pipeline

# %% [markdown]
# How to iterate if we do not know the earliest date available?
# Thankfully, another endpoint provides all data (daily); we will use it to get and define the earliest available record to be able to iterate over hourly data then.

# %%
BATCH_SIZE = 2000

# %%
def get_historical_earliest_date() -> int:
    
    request = requests.get(f"https://min-api.cryptocompare.com/data/v2/histoday?fsym={CRYPTO_CURRENCY}&tsym={LOCAL_CURRENCY}&allData=true&{API_KEY}")
    rep = json.loads(request.content)

    return rep["Data"]["TimeFrom"]

# %%
historical_earliest_date = get_historical_earliest_date()
print(historical_earliest_date, datetime.fromtimestamp(historical_earliest_date))
# Out:
# 1314403200 2011-08-27 02:00:00

# %%
def get_hourly_batch_data(toTs: int) -> int | list:

    request = requests.get(f"https://min-api.cryptocompare.com/data/v2/{API_ENDPOINT}?fsym={CRYPTO_CURRENCY}&tsym={LOCAL_CURRENCY}&limit={str(BATCH_SIZE)}&toTs={toTs}&{API_KEY}")
    
    if request.status_code != 200:
        raise Exception(request.content)

    rep = json.loads(request.content)
    data = rep["Data"]["Data"]
    batch_earliest_date = rep["Data"]["TimeFrom"]

    return (data, batch_earliest_date)

# %%
now = time.time()
hourly_data, batch_earliest_date = get_hourly_batch_data(now)
hourly_data, batch_earliest_date
# Out:
# ([{'time': 1739343600,
#    'high': 92810.04,
#    'low': 92513.66,
#    'open': 92536.28,
#    'volumefrom': 84.7,
#    'volumeto': 7842919.38,
#    'close': 92615.79,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739347200,
#    'high': 92994.99,
#    'low': 92610.11,
#    'open': 92615.79,
#    'volumefrom': 56.13,
#    'volumeto': 5207567.66,
#    'close': 92947.71,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739350800,
#    'high': 92959.12,
#    'low': 92633.52,
#    'open': 92947.71,
#    'volumefrom': 69.38,
#    'volumeto': 6434326.89,
#    'close': 92722.29,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739354400,
#    'high': 92775.4,
#    'low': 92501.71,
#    'open': 92722.29,
#    'volumefrom': 46.74,
#    'volumeto': 4330883.15,
#    'close': 92533.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739358000,
#    'high': 92862.33,
#    'low': 92532.97,
#    'open': 92533.05,
#    'volumefrom': 66.94,
#    'volumeto': 6204274.02,
#    'close': 92647.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739361600,
#    'high': 92907.7,
#    'low': 92540.46,
#    'open': 92647.66,
#    'volumefrom': 38.52,
#    'volumeto': 3572431.27,
#    'close': 92547.49,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739365200,
#    'high': 93203.82,
#    'low': 91263.25,
#    'open': 92547.49,
#    'volumefrom': 296.86,
#    'volumeto': 27349368.88,
#    'close': 91932.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739368800,
#    'high': 92476.75,
#    'low': 91424.16,
#    'open': 91932.97,
#    'volumefrom': 169.57,
#    'volumeto': 15592656.49,
#    'close': 92428.93,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739372400,
#    'high': 92684.83,
#    'low': 91678.12,
#    'open': 92428.93,
#    'volumefrom': 203.65,
#    'volumeto': 18794281.47,
#    'close': 92380.5,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739376000,
#    'high': 93492.01,
#    'low': 91891.97,
#    'open': 92380.5,
#    'volumefrom': 141.86,
#    'volumeto': 13130918.61,
#    'close': 93395.68,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739379600,
#    'high': 93802.02,
#    'low': 93008.55,
#    'open': 93395.68,
#    'volumefrom': 201.12,
#    'volumeto': 18789099.74,
#    'close': 93396.78,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739383200,
#    'high': 93468.83,
#    'low': 92854.49,
#    'open': 93396.78,
#    'volumefrom': 76.77,
#    'volumeto': 7149473.96,
#    'close': 93301.24,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739386800,
#    'high': 93634.74,
#    'low': 92788.45,
#    'open': 93301.24,
#    'volumefrom': 70.14,
#    'volumeto': 6535085.48,
#    'close': 93546.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739390400,
#    'high': 93931.15,
#    'low': 93298.49,
#    'open': 93546.07,
#    'volumefrom': 56.08,
#    'volumeto': 5248619.76,
#    'close': 93394.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739394000,
#    'high': 94273.39,
#    'low': 93268.22,
#    'open': 93394.66,
#    'volumefrom': 66.74,
#    'volumeto': 6266406.14,
#    'close': 94068.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739397600,
#    'high': 94442.72,
#    'low': 93810.63,
#    'open': 94068.01,
#    'volumefrom': 126.59,
#    'volumeto': 11918205.5,
#    'close': 94216.43,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739401200,
#    'high': 94353.09,
#    'low': 93969.61,
#    'open': 94216.43,
#    'volumefrom': 68.11,
#    'volumeto': 6413188.91,
#    'close': 94185.28,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739404800,
#    'high': 94185.28,
#    'low': 93863.87,
#    'open': 94185.28,
#    'volumefrom': 33.25,
#    'volumeto': 3123902.29,
#    'close': 94143.84,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739408400,
#    'high': 94315.4,
#    'low': 94061.22,
#    'open': 94143.84,
#    'volumefrom': 34.59,
#    'volumeto': 3257639.38,
#    'close': 94239.95,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739412000,
#    'high': 94240.04,
#    'low': 93636.9,
#    'open': 94239.95,
#    'volumefrom': 19.93,
#    'volumeto': 1871540.24,
#    'close': 93697.34,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739415600,
#    'high': 93809.98,
#    'low': 93607.07,
#    'open': 93697.34,
#    'volumefrom': 21.03,
#    'volumeto': 1970418.98,
#    'close': 93608.81,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739419200,
#    'high': 93643.07,
#    'low': 92836.17,
#    'open': 93608.81,
#    'volumefrom': 34.28,
#    'volumeto': 3195828.8,
#    'close': 92944.68,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739422800,
#    'high': 92944.68,
#    'low': 92541.26,
#    'open': 92944.68,
#    'volumefrom': 47.19,
#    'volumeto': 4374797.13,
#    'close': 92657.17,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739426400,
#    'high': 92727.6,
#    'low': 91866.86,
#    'open': 92657.17,
#    'volumefrom': 90.77,
#    'volumeto': 8371947.14,
#    'close': 92082.58,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739430000,
#    'high': 92250.76,
#    'low': 91965.17,
#    'open': 92082.58,
#    'volumefrom': 67.78,
#    'volumeto': 6243883,
#    'close': 92193.39,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739433600,
#    'high': 92314.05,
#    'low': 91968.52,
#    'open': 92193.39,
#    'volumefrom': 69.35,
#    'volumeto': 6392599.02,
#    'close': 92178.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739437200,
#    'high': 92500.62,
#    'low': 92047.55,
#    'open': 92178.72,
#    'volumefrom': 67.17,
#    'volumeto': 6203567.57,
#    'close': 92400.47,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739440800,
#    'high': 92437.03,
#    'low': 92290.8,
#    'open': 92400.47,
#    'volumefrom': 38.5,
#    'volumeto': 3556793.64,
#    'close': 92365.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739444400,
#    'high': 92416.41,
#    'low': 92022.81,
#    'open': 92365.62,
#    'volumefrom': 99.96,
#    'volumeto': 9219405.32,
#    'close': 92254.22,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739448000,
#    'high': 92475.33,
#    'low': 92210.04,
#    'open': 92254.22,
#    'volumefrom': 111.34,
#    'volumeto': 10283086.85,
#    'close': 92279.27,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739451600,
#    'high': 92661.54,
#    'low': 92152.57,
#    'open': 92279.27,
#    'volumefrom': 140.37,
#    'volumeto': 12976642.19,
#    'close': 92500.73,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739455200,
#    'high': 92550.22,
#    'low': 91864.92,
#    'open': 92500.73,
#    'volumefrom': 125.81,
#    'volumeto': 11607895.31,
#    'close': 92249.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739458800,
#    'high': 92531.48,
#    'low': 91822.41,
#    'open': 92249.8,
#    'volumefrom': 149.59,
#    'volumeto': 13782321.75,
#    'close': 92060.16,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739462400,
#    'high': 92062.7,
#    'low': 91382.44,
#    'open': 92060.16,
#    'volumefrom': 118.07,
#    'volumeto': 10814183.56,
#    'close': 91487.15,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739466000,
#    'high': 92075.62,
#    'low': 91464.17,
#    'open': 91487.15,
#    'volumefrom': 73.2,
#    'volumeto': 6719855.07,
#    'close': 91835.61,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739469600,
#    'high': 92216.21,
#    'low': 91549.98,
#    'open': 91835.61,
#    'volumefrom': 142.42,
#    'volumeto': 13092031.95,
#    'close': 92215.96,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739473200,
#    'high': 92442.08,
#    'low': 91642.93,
#    'open': 92215.96,
#    'volumefrom': 70.69,
#    'volumeto': 6505247.74,
#    'close': 91665.03,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739476800,
#    'high': 92114.6,
#    'low': 91652.69,
#    'open': 91665.03,
#    'volumefrom': 49.91,
#    'volumeto': 4588904.96,
#    'close': 92061.77,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739480400,
#    'high': 92517.4,
#    'low': 92056.14,
#    'open': 92061.77,
#    'volumefrom': 52.32,
#    'volumeto': 4828816.94,
#    'close': 92223.18,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739484000,
#    'high': 92327.13,
#    'low': 92028.32,
#    'open': 92223.18,
#    'volumefrom': 26.13,
#    'volumeto': 2408478.37,
#    'close': 92102.09,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739487600,
#    'high': 92388.35,
#    'low': 92062.81,
#    'open': 92102.09,
#    'volumefrom': 26.13,
#    'volumeto': 2409903.82,
#    'close': 92365.08,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739491200,
#    'high': 92685.42,
#    'low': 92326.12,
#    'open': 92365.08,
#    'volumefrom': 30.69,
#    'volumeto': 2838291.17,
#    'close': 92523.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739494800,
#    'high': 92643.11,
#    'low': 92171.59,
#    'open': 92523.07,
#    'volumefrom': 27.36,
#    'volumeto': 2527702.74,
#    'close': 92309.14,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739498400,
#    'high': 92842.48,
#    'low': 91969.14,
#    'open': 92311.26,
#    'volumefrom': 1478.2,
#    'volumeto': 136530625.4,
#    'close': 92362.76,
#    'conversionType': 'invert_divide',
#    'conversionSymbol': 'ETH'},
#   {'time': 1739502000,
#    'high': 92948.71,
#    'low': 92361.94,
#    'open': 92368.89,
#    'volumefrom': 21.83,
#    'volumeto': 2022659.58,
#    'close': 92895.23,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739505600,
#    'high': 92974.27,
#    'low': 92574.57,
#    'open': 92895.23,
#    'volumefrom': 17.01,
#    'volumeto': 1577740.29,
#    'close': 92574.99,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739509200,
#    'high': 92715.47,
#    'low': 92431.18,
#    'open': 92574.99,
#    'volumefrom': 26.92,
#    'volumeto': 2492469.77,
#    'close': 92531.21,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739512800,
#    'high': 92643.5,
#    'low': 92435.23,
#    'open': 92531.21,
#    'volumefrom': 30.85,
#    'volumeto': 2854809.59,
#    'close': 92602.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739516400,
#    'high': 92775.01,
#    'low': 92580.81,
#    'open': 92602.05,
#    'volumefrom': 48.29,
#    'volumeto': 4475433.31,
#    'close': 92685.17,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739520000,
#    'high': 92740.57,
#    'low': 92411.94,
#    'open': 92685.17,
#    'volumefrom': 72.07,
#    'volumeto': 6671331.42,
#    'close': 92524.75,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739523600,
#    'high': 92747.7,
#    'low': 92499.73,
#    'open': 92524.75,
#    'volumefrom': 58.07,
#    'volumeto': 5378501.04,
#    'close': 92691.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739527200,
#    'high': 92810.43,
#    'low': 92609.82,
#    'open': 92691.8,
#    'volumefrom': 53.86,
#    'volumeto': 4994069.73,
#    'close': 92740.64,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739530800,
#    'high': 92825.37,
#    'low': 92522.39,
#    'open': 92740.64,
#    'volumefrom': 56.26,
#    'volumeto': 5213890.83,
#    'close': 92586.88,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739534400,
#    'high': 92587.09,
#    'low': 92248.62,
#    'open': 92586.88,
#    'volumefrom': 47.31,
#    'volumeto': 4371026.01,
#    'close': 92339.78,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739538000,
#    'high': 92464.22,
#    'low': 92064.72,
#    'open': 92339.78,
#    'volumefrom': 79.23,
#    'volumeto': 7311383.61,
#    'close': 92353.74,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739541600,
#    'high': 92887.82,
#    'low': 92062.7,
#    'open': 92353.74,
#    'volumefrom': 112.6,
#    'volumeto': 10413434.51,
#    'close': 92639.57,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739545200,
#    'high': 92730.52,
#    'low': 91770.09,
#    'open': 92639.57,
#    'volumefrom': 136.75,
#    'volumeto': 12599552.3,
#    'close': 92284.44,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739548800,
#    'high': 93069.67,
#    'low': 91955.85,
#    'open': 92284.44,
#    'volumefrom': 127.83,
#    'volumeto': 11816325.1,
#    'close': 93041.19,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739552400,
#    'high': 94108.24,
#    'low': 92593.12,
#    'open': 93041.19,
#    'volumefrom': 151.68,
#    'volumeto': 14147013.63,
#    'close': 93840.64,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739556000,
#    'high': 94022.46,
#    'low': 93543.87,
#    'open': 93840.64,
#    'volumefrom': 92.14,
#    'volumeto': 8640487.42,
#    'close': 93555.31,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739559600,
#    'high': 93773.22,
#    'low': 93119.75,
#    'open': 93555.31,
#    'volumefrom': 109.19,
#    'volumeto': 10207992.38,
#    'close': 93323.31,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739563200,
#    'high': 93661.31,
#    'low': 92532.63,
#    'open': 93323.31,
#    'volumefrom': 70.18,
#    'volumeto': 6539668.12,
#    'close': 92671.59,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739566800,
#    'high': 92933.3,
#    'low': 92225.3,
#    'open': 92671.59,
#    'volumefrom': 61.91,
#    'volumeto': 5734205.15,
#    'close': 92920.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739570400,
#    'high': 93000.82,
#    'low': 92477.75,
#    'open': 92920.66,
#    'volumefrom': 30.91,
#    'volumeto': 2868704.74,
#    'close': 92627.22,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739574000,
#    'high': 92987.32,
#    'low': 92538.02,
#    'open': 92627.22,
#    'volumefrom': 28.2,
#    'volumeto': 2616974.84,
#    'close': 92978.55,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739577600,
#    'high': 92985.64,
#    'low': 92751.46,
#    'open': 92978.55,
#    'volumefrom': 28.23,
#    'volumeto': 2622340.98,
#    'close': 92953.47,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739581200,
#    'high': 93279.24,
#    'low': 92937.75,
#    'open': 92953.47,
#    'volumefrom': 14.42,
#    'volumeto': 1342850.57,
#    'close': 93265.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739584800,
#    'high': 93361.48,
#    'low': 93106.88,
#    'open': 93265.66,
#    'volumefrom': 12.09,
#    'volumeto': 1127874.6,
#    'close': 93285.37,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739588400,
#    'high': 93416.37,
#    'low': 93127.25,
#    'open': 93285.37,
#    'volumefrom': 14.02,
#    'volumeto': 1306950.68,
#    'close': 93129.15,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739592000,
#    'high': 93243.82,
#    'low': 92978.16,
#    'open': 93129.15,
#    'volumefrom': 13.1,
#    'volumeto': 1220350.59,
#    'close': 92996.03,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739595600,
#    'high': 93108.39,
#    'low': 92955.01,
#    'open': 92996.03,
#    'volumefrom': 7.103,
#    'volumeto': 660773.21,
#    'close': 93080.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739599200,
#    'high': 93126.51,
#    'low': 92933.5,
#    'open': 93080.05,
#    'volumefrom': 12.79,
#    'volumeto': 1190502.43,
#    'close': 92958.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739602800,
#    'high': 92994.97,
#    'low': 92861.87,
#    'open': 92958.05,
#    'volumefrom': 11.25,
#    'volumeto': 1045416.17,
#    'close': 92870.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739606400,
#    'high': 93038.13,
#    'low': 92818.5,
#    'open': 92870.8,
#    'volumefrom': 16.2,
#    'volumeto': 1505738.74,
#    'close': 93010.7,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739610000,
#    'high': 93091.09,
#    'low': 92955.67,
#    'open': 93010.7,
#    'volumefrom': 19.76,
#    'volumeto': 1837895.16,
#    'close': 93048.87,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739613600,
#    'high': 93197.79,
#    'low': 92971.68,
#    'open': 93048.87,
#    'volumefrom': 19.96,
#    'volumeto': 1857269.59,
#    'close': 93157.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739617200,
#    'high': 93163.8,
#    'low': 92999.93,
#    'open': 93157.01,
#    'volumefrom': 46.34,
#    'volumeto': 4313722.22,
#    'close': 93117.64,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739620800,
#    'high': 93317.01,
#    'low': 93059.07,
#    'open': 93117.64,
#    'volumefrom': 30.15,
#    'volumeto': 2808821.71,
#    'close': 93246.54,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739624400,
#    'high': 93401.77,
#    'low': 93171.17,
#    'open': 93246.54,
#    'volumefrom': 34.72,
#    'volumeto': 3238007.84,
#    'close': 93204.65,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739628000,
#    'high': 93246.36,
#    'low': 92966.64,
#    'open': 93204.65,
#    'volumefrom': 28.21,
#    'volumeto': 2626478.39,
#    'close': 93129.63,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739631600,
#    'high': 93216.28,
#    'low': 93068.36,
#    'open': 93129.63,
#    'volumefrom': 21.55,
#    'volumeto': 2007576.07,
#    'close': 93156.41,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739635200,
#    'high': 93216.04,
#    'low': 93008.16,
#    'open': 93156.41,
#    'volumefrom': 19.45,
#    'volumeto': 1810537.69,
#    'close': 93047.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739638800,
#    'high': 93101.55,
#    'low': 92869.35,
#    'open': 93047.85,
#    'volumefrom': 25.08,
#    'volumeto': 2332113.22,
#    'close': 92949.65,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739642400,
#    'high': 93107.25,
#    'low': 92921.74,
#    'open': 92949.65,
#    'volumefrom': 22.04,
#    'volumeto': 2049927.48,
#    'close': 93072.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739646000,
#    'high': 93175.19,
#    'low': 93062.26,
#    'open': 93072.85,
#    'volumefrom': 14.25,
#    'volumeto': 1326984.64,
#    'close': 93074.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739649600,
#    'high': 93155.6,
#    'low': 92940.93,
#    'open': 93074.85,
#    'volumefrom': 23.98,
#    'volumeto': 2231300.39,
#    'close': 93041.17,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739653200,
#    'high': 93200.35,
#    'low': 93038.58,
#    'open': 93041.17,
#    'volumefrom': 16.53,
#    'volumeto': 1539556.99,
#    'close': 93184.46,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739656800,
#    'high': 93240.98,
#    'low': 92982.27,
#    'open': 93184.46,
#    'volumefrom': 14.28,
#    'volumeto': 1329562.15,
#    'close': 93057.06,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739660400,
#    'high': 93148.22,
#    'low': 92974.1,
#    'open': 93057.06,
#    'volumefrom': 27.58,
#    'volumeto': 2565954.87,
#    'close': 93104.2,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739664000,
#    'high': 93220.42,
#    'low': 93091.66,
#    'open': 93104.2,
#    'volumefrom': 11.57,
#    'volumeto': 1078166.57,
#    'close': 93122.63,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739667600,
#    'high': 93161.56,
#    'low': 93063.93,
#    'open': 93122.63,
#    'volumefrom': 8.621,
#    'volumeto': 802758.83,
#    'close': 93153.42,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739671200,
#    'high': 93166.35,
#    'low': 93005.6,
#    'open': 93153.42,
#    'volumefrom': 14.13,
#    'volumeto': 1315417.3,
#    'close': 93048.36,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739674800,
#    'high': 93050.61,
#    'low': 92968.58,
#    'open': 93048.36,
#    'volumefrom': 15.14,
#    'volumeto': 1407582.89,
#    'close': 93050.36,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739678400,
#    'high': 93087.14,
#    'low': 92998.34,
#    'open': 93050.36,
#    'volumefrom': 10.66,
#    'volumeto': 992013.5,
#    'close': 93052.79,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739682000,
#    'high': 93165.99,
#    'low': 93013.52,
#    'open': 93052.79,
#    'volumefrom': 14.26,
#    'volumeto': 1327325.02,
#    'close': 93108.02,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739685600,
#    'high': 93108.14,
#    'low': 92957.15,
#    'open': 93108.02,
#    'volumefrom': 50.33,
#    'volumeto': 4659651.81,
#    'close': 92975.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739689200,
#    'high': 92975.72,
#    'low': 92742.16,
#    'open': 92975.72,
#    'volumefrom': 12.1,
#    'volumeto': 1123651.19,
#    'close': 92768.5,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739692800,
#    'high': 92820.43,
#    'low': 92668.24,
#    'open': 92768.5,
#    'volumefrom': 17.87,
#    'volumeto': 1657581.17,
#    'close': 92682.9,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739696400,
#    'high': 92871.98,
#    'low': 92600.74,
#    'open': 92682.9,
#    'volumefrom': 23.84,
#    'volumeto': 2210115.67,
#    'close': 92870.83,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739700000,
#    'high': 92896.15,
#    'low': 92709.94,
#    'open': 92870.83,
#    'volumefrom': 18.8,
#    'volumeto': 1745354.53,
#    'close': 92710.48,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739703600,
#    'high': 92819.41,
#    'low': 92683.99,
#    'open': 92710.48,
#    'volumefrom': 14.59,
#    'volumeto': 1353504.35,
#    'close': 92813.1,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739707200,
#    'high': 92813.27,
#    'low': 92618.54,
#    'open': 92813.1,
#    'volumefrom': 14.24,
#    'volumeto': 1320288.73,
#    'close': 92642.55,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739710800,
#    'high': 92701.52,
#    'low': 92358.91,
#    'open': 92642.55,
#    'volumefrom': 51.63,
#    'volumeto': 4777308.93,
#    'close': 92393.54,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739714400,
#    'high': 92541.68,
#    'low': 92246.6,
#    'open': 92393.54,
#    'volumefrom': 42.55,
#    'volumeto': 3929703.05,
#    'close': 92508.64,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739718000,
#    'high': 92598.49,
#    'low': 92471.01,
#    'open': 92508.64,
#    'volumefrom': 19.21,
#    'volumeto': 1777684.89,
#    'close': 92471.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739721600,
#    'high': 92634.31,
#    'low': 92442.61,
#    'open': 92471.01,
#    'volumefrom': 19.05,
#    'volumeto': 1762738.48,
#    'close': 92578.39,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739725200,
#    'high': 92675.46,
#    'low': 92491.83,
#    'open': 92578.39,
#    'volumefrom': 15.12,
#    'volumeto': 1399512.95,
#    'close': 92518.67,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739728800,
#    'high': 92527.02,
#    'low': 92260.27,
#    'open': 92518.67,
#    'volumefrom': 38.82,
#    'volumeto': 3586699.28,
#    'close': 92448.99,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739732400,
#    'high': 92644.89,
#    'low': 92369.49,
#    'open': 92448.99,
#    'volumefrom': 27.05,
#    'volumeto': 2503059.95,
#    'close': 92589.7,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739736000,
#    'high': 92661.34,
#    'low': 92434.23,
#    'open': 92589.7,
#    'volumefrom': 24.8,
#    'volumeto': 2295546.99,
#    'close': 92459.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739739600,
#    'high': 92796.87,
#    'low': 92446.55,
#    'open': 92459.62,
#    'volumefrom': 35.99,
#    'volumeto': 3334585.92,
#    'close': 92706.98,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739743200,
#    'high': 92717.31,
#    'low': 92150.04,
#    'open': 92706.98,
#    'volumefrom': 27.13,
#    'volumeto': 2507719.78,
#    'close': 92399.28,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739746800,
#    'high': 92412.05,
#    'low': 91649.39,
#    'open': 92399.28,
#    'volumefrom': 74.87,
#    'volumeto': 6878754.8,
#    'close': 91706.84,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739750400,
#    'high': 91995.28,
#    'low': 91631.01,
#    'open': 91706.84,
#    'volumefrom': 29.71,
#    'volumeto': 2728573.8,
#    'close': 91844.27,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739754000,
#    'high': 91939.17,
#    'low': 91595.94,
#    'open': 91844.27,
#    'volumefrom': 29.89,
#    'volumeto': 2743176.09,
#    'close': 91916.18,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739757600,
#    'high': 92025.92,
#    'low': 91649.8,
#    'open': 91916.18,
#    'volumefrom': 22.29,
#    'volumeto': 2046939.4,
#    'close': 91681.49,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739761200,
#    'high': 91747.75,
#    'low': 91514.69,
#    'open': 91681.49,
#    'volumefrom': 20.02,
#    'volumeto': 1834273.87,
#    'close': 91721.31,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739764800,
#    'high': 91777.45,
#    'low': 91555.11,
#    'open': 91721.31,
#    'volumefrom': 18.2,
#    'volumeto': 1667648.24,
#    'close': 91555.11,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739768400,
#    'high': 91833,
#    'low': 91361.53,
#    'open': 91555.11,
#    'volumefrom': 44.36,
#    'volumeto': 4063694.36,
#    'close': 91792.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739772000,
#    'high': 91977.39,
#    'low': 91790.8,
#    'open': 91792.72,
#    'volumefrom': 37.87,
#    'volumeto': 3479413.87,
#    'close': 91906.04,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739775600,
#    'high': 91993.32,
#    'low': 91515.45,
#    'open': 91906.04,
#    'volumefrom': 55.49,
#    'volumeto': 5087457.66,
#    'close': 91679.89,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739779200,
#    'high': 91945.66,
#    'low': 91584.96,
#    'open': 91679.89,
#    'volumefrom': 56.06,
#    'volumeto': 5143705.72,
#    'close': 91837.78,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739782800,
#    'high': 91988.16,
#    'low': 91798.21,
#    'open': 91837.78,
#    'volumefrom': 43.24,
#    'volumeto': 3973560.36,
#    'close': 91855.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739786400,
#    'high': 92008.65,
#    'low': 91649.76,
#    'open': 91855.85,
#    'volumefrom': 63,
#    'volumeto': 5784463.79,
#    'close': 91687.46,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739790000,
#    'high': 91881.91,
#    'low': 91629.59,
#    'open': 91687.46,
#    'volumefrom': 50.11,
#    'volumeto': 4595798.31,
#    'close': 91674.11,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739793600,
#    'high': 92162.87,
#    'low': 91667.9,
#    'open': 91674.11,
#    'volumefrom': 61.37,
#    'volumeto': 5641318.42,
#    'close': 92125.78,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739797200,
#    'high': 92143.06,
#    'low': 91975.96,
#    'open': 92125.78,
#    'volumefrom': 54.73,
#    'volumeto': 5037344.11,
#    'close': 92078.16,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739800800,
#    'high': 92636.98,
#    'low': 92067.04,
#    'open': 92078.16,
#    'volumefrom': 93.23,
#    'volumeto': 8611957,
#    'close': 92397.46,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739804400,
#    'high': 92482.17,
#    'low': 91246.18,
#    'open': 92397.46,
#    'volumefrom': 114.11,
#    'volumeto': 10473992.08,
#    'close': 91332.9,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739808000,
#    'high': 91570.53,
#    'low': 90995.08,
#    'open': 91332.9,
#    'volumefrom': 100.21,
#    'volumeto': 9139261.32,
#    'close': 91035.58,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739811600,
#    'high': 91366.58,
#    'low': 90966.22,
#    'open': 91035.58,
#    'volumefrom': 77.35,
#    'volumeto': 7050666.61,
#    'close': 91150.02,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739815200,
#    'high': 91435.47,
#    'low': 90949.68,
#    'open': 91150.02,
#    'volumefrom': 77.28,
#    'volumeto': 7038535.79,
#    'close': 91004.82,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739818800,
#    'high': 91251.08,
#    'low': 90894.42,
#    'open': 91004.82,
#    'volumefrom': 60.34,
#    'volumeto': 5492840.04,
#    'close': 91197.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739822400,
#    'high': 91862.58,
#    'low': 91175.13,
#    'open': 91197.72,
#    'volumefrom': 65.25,
#    'volumeto': 5974830.83,
#    'close': 91612.57,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739826000,
#    'high': 91958.91,
#    'low': 91558.35,
#    'open': 91612.57,
#    'volumefrom': 105.93,
#    'volumeto': 9718697.42,
#    'close': 91954.82,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739829600,
#    'high': 91974.82,
#    'low': 91473.9,
#    'open': 91954.82,
#    'volumefrom': 34.95,
#    'volumeto': 3207795.42,
#    'close': 91495.9,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739833200,
#    'high': 91613.19,
#    'low': 91320.82,
#    'open': 91495.9,
#    'volumefrom': 31.15,
#    'volumeto': 2849485.69,
#    'close': 91367.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739836800,
#    'high': 91611.36,
#    'low': 91211.24,
#    'open': 91367.97,
#    'volumefrom': 33.25,
#    'volumeto': 3039718.89,
#    'close': 91310.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739840400,
#    'high': 92001.04,
#    'low': 91302.2,
#    'open': 91310.72,
#    'volumefrom': 32.48,
#    'volumeto': 2979488.41,
#    'close': 91992.19,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739844000,
#    'high': 92019.7,
#    'low': 91749.34,
#    'open': 91992.19,
#    'volumefrom': 14.17,
#    'volumeto': 1301843.51,
#    'close': 91782.92,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739847600,
#    'high': 92004.86,
#    'low': 91735.63,
#    'open': 91782.92,
#    'volumefrom': 12.82,
#    'volumeto': 1178462.11,
#    'close': 91946.69,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739851200,
#    'high': 92038.24,
#    'low': 91815.38,
#    'open': 91946.69,
#    'volumefrom': 16.81,
#    'volumeto': 1545632.86,
#    'close': 91873.33,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739854800,
#    'high': 91884.52,
#    'low': 91440.61,
#    'open': 91873.33,
#    'volumefrom': 32.3,
#    'volumeto': 2959649.45,
#    'close': 91451.5,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739858400,
#    'high': 91474.01,
#    'low': 91127.96,
#    'open': 91451.5,
#    'volumefrom': 51.45,
#    'volumeto': 4694552.65,
#    'close': 91181.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739862000,
#    'high': 91480.54,
#    'low': 91091,
#    'open': 91181.66,
#    'volumefrom': 69.72,
#    'volumeto': 6362508.9,
#    'close': 91260.51,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739865600,
#    'high': 91300.2,
#    'low': 90913.09,
#    'open': 91260.51,
#    'volumefrom': 84.38,
#    'volumeto': 7687070.68,
#    'close': 91080.95,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739869200,
#    'high': 91534.47,
#    'low': 91019.79,
#    'open': 91080.95,
#    'volumefrom': 87.63,
#    'volumeto': 8012433.6,
#    'close': 91517.94,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739872800,
#    'high': 91665.64,
#    'low': 91432.07,
#    'open': 91517.94,
#    'volumefrom': 43.52,
#    'volumeto': 3983331.06,
#    'close': 91521.81,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739876400,
#    'high': 91531.75,
#    'low': 91354.19,
#    'open': 91521.81,
#    'volumefrom': 46.38,
#    'volumeto': 4241125.72,
#    'close': 91420.84,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739880000,
#    'high': 92020.51,
#    'low': 91389.73,
#    'open': 91420.84,
#    'volumefrom': 82.04,
#    'volumeto': 7532030.22,
#    'close': 91991.64,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739883600,
#    'high': 92295.53,
#    'low': 91986.14,
#    'open': 91991.64,
#    'volumefrom': 98.45,
#    'volumeto': 9067866.14,
#    'close': 92135.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739887200,
#    'high': 92547.27,
#    'low': 91337.09,
#    'open': 92135.62,
#    'volumefrom': 120.73,
#    'volumeto': 11114693.99,
#    'close': 91389.17,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739890800,
#    'high': 91541.62,
#    'low': 91037.17,
#    'open': 91389.17,
#    'volumefrom': 106.75,
#    'volumeto': 9748071.76,
#    'close': 91290.16,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739894400,
#    'high': 91375.57,
#    'low': 90493.16,
#    'open': 91290.16,
#    'volumefrom': 132.76,
#    'volumeto': 12057617.44,
#    'close': 90508.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739898000,
#    'high': 90748.72,
#    'low': 90092.98,
#    'open': 90508.85,
#    'volumefrom': 140.53,
#    'volumeto': 12699726.93,
#    'close': 90093.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739901600,
#    'high': 90298.29,
#    'low': 89635.53,
#    'open': 90093.07,
#    'volumefrom': 298.02,
#    'volumeto': 26805705.97,
#    'close': 89925.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739905200,
#    'high': 90306.53,
#    'low': 89432.31,
#    'open': 89925.97,
#    'volumefrom': 152.2,
#    'volumeto': 13660350.57,
#    'close': 90065.81,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739908800,
#    'high': 90367.37,
#    'low': 89748.23,
#    'open': 90065.81,
#    'volumefrom': 97.85,
#    'volumeto': 8814312.3,
#    'close': 90134.21,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739912400,
#    'high': 91165.19,
#    'low': 90074.74,
#    'open': 90134.21,
#    'volumefrom': 152.87,
#    'volumeto': 13882574.52,
#    'close': 90902.67,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739916000,
#    'high': 91316.63,
#    'low': 90763.31,
#    'open': 90902.67,
#    'volumefrom': 50.82,
#    'volumeto': 4626505.29,
#    'close': 91130.06,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739919600,
#    'high': 91486.12,
#    'low': 91123.34,
#    'open': 91130.06,
#    'volumefrom': 31.1,
#    'volumeto': 2839475.73,
#    'close': 91478.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739923200,
#    'high': 91661.34,
#    'low': 91178.37,
#    'open': 91478.85,
#    'volumefrom': 35.11,
#    'volumeto': 3208749.13,
#    'close': 91216.26,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739926800,
#    'high': 91333.7,
#    'low': 90946.17,
#    'open': 91216.26,
#    'volumefrom': 22.68,
#    'volumeto': 2066545.24,
#    'close': 91333.7,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739930400,
#    'high': 91737.7,
#    'low': 91320.85,
#    'open': 91333.7,
#    'volumefrom': 39.03,
#    'volumeto': 3574480.08,
#    'close': 91608.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739934000,
#    'high': 91622.52,
#    'low': 91420.27,
#    'open': 91608.66,
#    'volumefrom': 14.04,
#    'volumeto': 1285452.67,
#    'close': 91510.22,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739937600,
#    'high': 91558.99,
#    'low': 91116.07,
#    'open': 91510.22,
#    'volumefrom': 9.185,
#    'volumeto': 839036.28,
#    'close': 91116.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739941200,
#    'high': 91164.32,
#    'low': 90933.26,
#    'open': 91116.07,
#    'volumefrom': 18.13,
#    'volumeto': 1651318.27,
#    'close': 91082.45,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739944800,
#    'high': 91459.75,
#    'low': 91051.07,
#    'open': 91082.45,
#    'volumefrom': 71.13,
#    'volumeto': 6504325.82,
#    'close': 91440.44,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739948400,
#    'high': 91632.01,
#    'low': 91423.09,
#    'open': 91440.44,
#    'volumefrom': 39.85,
#    'volumeto': 3647876.77,
#    'close': 91547.23,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739952000,
#    'high': 91704.03,
#    'low': 91535.89,
#    'open': 91547.23,
#    'volumefrom': 61.74,
#    'volumeto': 5656933.03,
#    'close': 91582.93,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739955600,
#    'high': 91957.73,
#    'low': 91580.25,
#    'open': 91582.93,
#    'volumefrom': 54.24,
#    'volumeto': 4976080.41,
#    'close': 91927.57,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739959200,
#    'high': 92418.95,
#    'low': 91927.55,
#    'open': 91927.57,
#    'volumefrom': 84.95,
#    'volumeto': 7838857.06,
#    'close': 92336.3,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739962800,
#    'high': 92405.68,
#    'low': 92203.76,
#    'open': 92336.3,
#    'volumefrom': 105.66,
#    'volumeto': 9753547.39,
#    'close': 92404.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739966400,
#    'high': 92506.21,
#    'low': 92194.77,
#    'open': 92404.62,
#    'volumefrom': 57.87,
#    'volumeto': 5344643.89,
#    'close': 92199.47,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739970000,
#    'high': 92449.96,
#    'low': 92179.61,
#    'open': 92199.47,
#    'volumefrom': 49.78,
#    'volumeto': 4594833.81,
#    'close': 92257.28,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739973600,
#    'high': 92692.27,
#    'low': 91737.07,
#    'open': 92257.28,
#    'volumefrom': 99.27,
#    'volumeto': 9160823.13,
#    'close': 91756.76,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739977200,
#    'high': 92315.97,
#    'low': 91559,
#    'open': 91756.76,
#    'volumefrom': 87.03,
#    'volumeto': 8005131.47,
#    'close': 92001.04,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739980800,
#    'high': 92524.96,
#    'low': 91998.62,
#    'open': 92001.04,
#    'volumefrom': 55.92,
#    'volumeto': 5163982.25,
#    'close': 92487.5,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739984400,
#    'high': 92627.91,
#    'low': 92276.06,
#    'open': 92487.5,
#    'volumefrom': 59.26,
#    'volumeto': 5483972.93,
#    'close': 92551.39,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739988000,
#    'high': 92558.4,
#    'low': 91757.07,
#    'open': 92551.39,
#    'volumefrom': 68.86,
#    'volumeto': 6339666.74,
#    'close': 91765.71,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739991600,
#    'high': 92225.61,
#    'low': 91498.83,
#    'open': 91765.71,
#    'volumefrom': 63.05,
#    'volumeto': 5795004.12,
#    'close': 92211.46,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739995200,
#    'high': 92462.94,
#    'low': 92125.59,
#    'open': 92211.46,
#    'volumefrom': 43.48,
#    'volumeto': 4014892.22,
#    'close': 92192.19,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1739998800,
#    'high': 92480.56,
#    'low': 92115.05,
#    'open': 92192.19,
#    'volumefrom': 30.68,
#    'volumeto': 2832559.72,
#    'close': 92338.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740002400,
#    'high': 92591.91,
#    'low': 92338.05,
#    'open': 92338.85,
#    'volumefrom': 33.56,
#    'volumeto': 3103498.96,
#    'close': 92528.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740006000,
#    'high': 92830.34,
#    'low': 92528.97,
#    'open': 92528.97,
#    'volumefrom': 30.1,
#    'volumeto': 2790273.69,
#    'close': 92661.88,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740009600,
#    'high': 92764.85,
#    'low': 92460.77,
#    'open': 92661.88,
#    'volumefrom': 19.82,
#    'volumeto': 1834971.65,
#    'close': 92764.56,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740013200,
#    'high': 92890.39,
#    'low': 92637.22,
#    'open': 92764.56,
#    'volumefrom': 25.42,
#    'volumeto': 2357667.48,
#    'close': 92766.35,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740016800,
#    'high': 93125.57,
#    'low': 92718.42,
#    'open': 92766.35,
#    'volumefrom': 46.04,
#    'volumeto': 4278132.73,
#    'close': 93033.68,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740020400,
#    'high': 93238.38,
#    'low': 92955,
#    'open': 93033.68,
#    'volumefrom': 34.95,
#    'volumeto': 3253561.67,
#    'close': 93011.81,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740024000,
#    'high': 93317,
#    'low': 93007.71,
#    'open': 93011.81,
#    'volumefrom': 26.91,
#    'volumeto': 2507721.48,
#    'close': 93183.18,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740027600,
#    'high': 93184.2,
#    'low': 92911.38,
#    'open': 93183.18,
#    'volumefrom': 24.44,
#    'volumeto': 2274870.13,
#    'close': 92920.48,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740031200,
#    'high': 92921.29,
#    'low': 92775.49,
#    'open': 92920.48,
#    'volumefrom': 21.35,
#    'volumeto': 1982484.56,
#    'close': 92899.23,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740034800,
#    'high': 93059.8,
#    'low': 92809.64,
#    'open': 92899.23,
#    'volumefrom': 28.57,
#    'volumeto': 2654589.55,
#    'close': 92886.36,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740038400,
#    'high': 93157.74,
#    'low': 92759.29,
#    'open': 92886.36,
#    'volumefrom': 44.83,
#    'volumeto': 4167195.21,
#    'close': 93119.95,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740042000,
#    'high': 93235.37,
#    'low': 93119.88,
#    'open': 93119.95,
#    'volumefrom': 46.54,
#    'volumeto': 4335973.21,
#    'close': 93140.39,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740045600,
#    'high': 93240.6,
#    'low': 93014.21,
#    'open': 93140.39,
#    'volumefrom': 49.96,
#    'volumeto': 4652195.05,
#    'close': 93239.7,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740049200,
#    'high': 93246,
#    'low': 93128.69,
#    'open': 93239.7,
#    'volumefrom': 35.65,
#    'volumeto': 3322396.28,
#    'close': 93144.25,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740052800,
#    'high': 93444.26,
#    'low': 93143.91,
#    'open': 93144.25,
#    'volumefrom': 64.84,
#    'volumeto': 6064527.75,
#    'close': 93374.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740056400,
#    'high': 93449.52,
#    'low': 93142.41,
#    'open': 93374.62,
#    'volumefrom': 69.28,
#    'volumeto': 6462376.58,
#    'close': 93431.44,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740060000,
#    'high': 93819.28,
#    'low': 92775.85,
#    'open': 93431.44,
#    'volumefrom': 129.83,
#    'volumeto': 12138473.58,
#    'close': 92886.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740063600,
#    'high': 93105.45,
#    'low': 92519.67,
#    'open': 92886.07,
#    'volumefrom': 138.7,
#    'volumeto': 12876424.96,
#    'close': 92545.88,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740067200,
#    'high': 93559.55,
#    'low': 92545.69,
#    'open': 92545.88,
#    'volumefrom': 92.12,
#    'volumeto': 8586245.45,
#    'close': 93143.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740070800,
#    'high': 93452.13,
#    'low': 93141.68,
#    'open': 93143.8,
#    'volumefrom': 52.11,
#    'volumeto': 4863484.91,
#    'close': 93417.41,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740074400,
#    'high': 93821.6,
#    'low': 93407.62,
#    'open': 93417.41,
#    'volumefrom': 58.93,
#    'volumeto': 5518409.56,
#    'close': 93673.12,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740078000,
#    'high': 93909.46,
#    'low': 93639.74,
#    'open': 93673.12,
#    'volumefrom': 48.76,
#    'volumeto': 4572044.65,
#    'close': 93761.52,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740081600,
#    'high': 94031.5,
#    'low': 93692.83,
#    'open': 93761.52,
#    'volumefrom': 64.42,
#    'volumeto': 6046690.39,
#    'close': 93763.61,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740085200,
#    'high': 93802.85,
#    'low': 93344.46,
#    'open': 93763.61,
#    'volumefrom': 44.45,
#    'volumeto': 4155637.96,
#    'close': 93412.82,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740088800,
#    'high': 93696.16,
#    'low': 93412.8,
#    'open': 93412.82,
#    'volumefrom': 22.09,
#    'volumeto': 2065567.58,
#    'close': 93490.54,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740092400,
#    'high': 93805.12,
#    'low': 93484.77,
#    'open': 93490.54,
#    'volumefrom': 19.67,
#    'volumeto': 1842514.32,
#    'close': 93639.51,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740096000,
#    'high': 93825.54,
#    'low': 93507.35,
#    'open': 93639.51,
#    'volumefrom': 23.17,
#    'volumeto': 2170478.32,
#    'close': 93626.54,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740099600,
#    'high': 93784.75,
#    'low': 93531.35,
#    'open': 93626.54,
#    'volumefrom': 15.16,
#    'volumeto': 1419809.56,
#    'close': 93762.62,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740103200,
#    'high': 93777.11,
#    'low': 93473.15,
#    'open': 93762.62,
#    'volumefrom': 12.98,
#    'volumeto': 1216048.1,
#    'close': 93476.21,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740106800,
#    'high': 93606.87,
#    'low': 93447.86,
#    'open': 93476.21,
#    'volumefrom': 12.54,
#    'volumeto': 1172102.69,
#    'close': 93473.37,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740110400,
#    'high': 93602.13,
#    'low': 93465.38,
#    'open': 93473.37,
#    'volumefrom': 8.366,
#    'volumeto': 782547.49,
#    'close': 93566.03,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740114000,
#    'high': 93771.82,
#    'low': 93544.06,
#    'open': 93566.03,
#    'volumefrom': 16.59,
#    'volumeto': 1553538.31,
#    'close': 93732.51,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740117600,
#    'high': 93844.66,
#    'low': 93709.79,
#    'open': 93732.51,
#    'volumefrom': 46.9,
#    'volumeto': 4397295.36,
#    'close': 93844.51,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740121200,
#    'high': 93957.06,
#    'low': 93597.71,
#    'open': 93844.51,
#    'volumefrom': 47.62,
#    'volumeto': 4464067.73,
#    'close': 93605.37,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740124800,
#    'high': 93819.47,
#    'low': 93605.34,
#    'open': 93605.37,
#    'volumefrom': 103.18,
#    'volumeto': 9670112.14,
#    'close': 93758.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740128400,
#    'high': 94440.31,
#    'low': 93691.06,
#    'open': 93758.01,
#    'volumefrom': 148.55,
#    'volumeto': 13971303.56,
#    'close': 93936.68,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740132000,
#    'high': 94232.91,
#    'low': 93838.15,
#    'open': 93936.68,
#    'volumefrom': 61.16,
#    'volumeto': 5749941.95,
#    'close': 94207.96,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740135600,
#    'high': 94366.25,
#    'low': 94126.87,
#    'open': 94207.96,
#    'volumefrom': 81.72,
#    'volumeto': 7703072.59,
#    'close': 94217.06,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1740139200,
#    'high': 94571.76,
#    'low': 94153.52,
#    'open': 94217.06,
# ...
#    'open': 77619.18,
#    'volumefrom': 24,
#    'volumeto': 1863057.25,
#    'close': 77651.68,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742680800,
#    'high': 77711.22,
#    'low': 77615.52,
#    'open': 77651.68,
#    'volumefrom': 12.89,
#    'volumeto': 1001386.09,
#    'close': 77617.88,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742684400,
#    'high': 77617.88,
#    'low': 77356,
#    'open': 77617.88,
#    'volumefrom': 25.36,
#    'volumeto': 1964553.69,
#    'close': 77493.71,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742688000,
#    'high': 77687.06,
#    'low': 77473.49,
#    'open': 77493.71,
#    'volumefrom': 17.75,
#    'volumeto': 1377313.89,
#    'close': 77651.1,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742691600,
#    'high': 77763.29,
#    'low': 77627.34,
#    'open': 77651.1,
#    'volumefrom': 8.484,
#    'volumeto': 659386.88,
#    'close': 77712.47,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742695200,
#    'high': 77894.24,
#    'low': 77649.24,
#    'open': 77712.47,
#    'volumefrom': 8.589,
#    'volumeto': 668346.04,
#    'close': 77856.28,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742698800,
#    'high': 77869.07,
#    'low': 77771.26,
#    'open': 77856.28,
#    'volumefrom': 5.597,
#    'volumeto': 435552.92,
#    'close': 77850.46,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742702400,
#    'high': 78063.5,
#    'low': 77706.9,
#    'open': 77828.86,
#    'volumefrom': 616.3,
#    'volumeto': 47919268.76,
#    'close': 77753.15,
#    'conversionType': 'invert_divide',
#    'conversionSymbol': 'ETH'},
#   {'time': 1742706000,
#    'high': 77901.01,
#    'low': 77598.15,
#    'open': 77753.15,
#    'volumefrom': 650.16,
#    'volumeto': 50627581.26,
#    'close': 77869.42,
#    'conversionType': 'invert_divide',
#    'conversionSymbol': 'ETH'},
#   {'time': 1742709600,
#    'high': 77911,
#    'low': 77828.77,
#    'open': 77861.04,
#    'volumefrom': 7.301,
#    'volumeto': 568555.99,
#    'close': 77869.29,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742713200,
#    'high': 77940.47,
#    'low': 77839.99,
#    'open': 77869.29,
#    'volumefrom': 14.17,
#    'volumeto': 1103346.94,
#    'close': 77900.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742716800,
#    'high': 77956.03,
#    'low': 77895.99,
#    'open': 77900.01,
#    'volumefrom': 19.74,
#    'volumeto': 1538248.73,
#    'close': 77946.87,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742720400,
#    'high': 77967.89,
#    'low': 77932.32,
#    'open': 77946.87,
#    'volumefrom': 13.35,
#    'volumeto': 1040722.47,
#    'close': 77946.14,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742724000,
#    'high': 78080.75,
#    'low': 77926.38,
#    'open': 77946.14,
#    'volumefrom': 23.05,
#    'volumeto': 1798250.55,
#    'close': 78049.32,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742727600,
#    'high': 78554.64,
#    'low': 78048.94,
#    'open': 78049.32,
#    'volumefrom': 66.29,
#    'volumeto': 5194915.63,
#    'close': 78255.56,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742731200,
#    'high': 78383.26,
#    'low': 78176.18,
#    'open': 78255.56,
#    'volumefrom': 18.78,
#    'volumeto': 1470537.84,
#    'close': 78313.15,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742734800,
#    'high': 78653.09,
#    'low': 78247.28,
#    'open': 78313.15,
#    'volumefrom': 44.51,
#    'volumeto': 3493000.4,
#    'close': 78637.43,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742738400,
#    'high': 78750.17,
#    'low': 78441.55,
#    'open': 78637.43,
#    'volumefrom': 36.47,
#    'volumeto': 2866195.64,
#    'close': 78481.54,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742742000,
#    'high': 78810.57,
#    'low': 78477.96,
#    'open': 78481.54,
#    'volumefrom': 28.65,
#    'volumeto': 2254158.74,
#    'close': 78764.01,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742745600,
#    'high': 78927.98,
#    'low': 78572.76,
#    'open': 78764.01,
#    'volumefrom': 61.13,
#    'volumeto': 4815672.91,
#    'close': 78848.99,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742749200,
#    'high': 78979.11,
#    'low': 78505.43,
#    'open': 78848.99,
#    'volumefrom': 50.99,
#    'volumeto': 4016194.45,
#    'close': 78591.03,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742752800,
#    'high': 78612.24,
#    'low': 78388.14,
#    'open': 78591.03,
#    'volumefrom': 41.7,
#    'volumeto': 3273219.99,
#    'close': 78536.49,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742756400,
#    'high': 78647.99,
#    'low': 78488.9,
#    'open': 78536.49,
#    'volumefrom': 23.43,
#    'volumeto': 1841074.41,
#    'close': 78582.7,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742760000,
#    'high': 78812.2,
#    'low': 78581.67,
#    'open': 78582.7,
#    'volumefrom': 30.52,
#    'volumeto': 2402679.52,
#    'close': 78677.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742763600,
#    'high': 78720.34,
#    'low': 78507.44,
#    'open': 78677.05,
#    'volumefrom': 31.52,
#    'volumeto': 2476529.51,
#    'close': 78717.48,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742767200,
#    'high': 79149.49,
#    'low': 78695.71,
#    'open': 78717.48,
#    'volumefrom': 80.74,
#    'volumeto': 6368081.33,
#    'close': 78889.04,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742770800,
#    'high': 79467.87,
#    'low': 78888.52,
#    'open': 78889.04,
#    'volumefrom': 52.95,
#    'volumeto': 4193985.27,
#    'close': 79442.1,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742774400,
#    'high': 79930.6,
#    'low': 79245.34,
#    'open': 79442.1,
#    'volumefrom': 76.76,
#    'volumeto': 6107153.77,
#    'close': 79392.26,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742778000,
#    'high': 79395.53,
#    'low': 79027.71,
#    'open': 79392.26,
#    'volumefrom': 32.47,
#    'volumeto': 2571644.34,
#    'close': 79033.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742781600,
#    'high': 79375.99,
#    'low': 79017.25,
#    'open': 79033.97,
#    'volumefrom': 23.16,
#    'volumeto': 1833542.58,
#    'close': 79341.27,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742785200,
#    'high': 79986.91,
#    'low': 79325.84,
#    'open': 79341.27,
#    'volumefrom': 50.84,
#    'volumeto': 4053337.28,
#    'close': 79973.18,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742788800,
#    'high': 80301.49,
#    'low': 79970.11,
#    'open': 79973.18,
#    'volumefrom': 71.03,
#    'volumeto': 5693046.48,
#    'close': 80268.32,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742792400,
#    'high': 80414.74,
#    'low': 80214.92,
#    'open': 80268.32,
#    'volumefrom': 41.04,
#    'volumeto': 3296957,
#    'close': 80262.58,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742796000,
#    'high': 80565.53,
#    'low': 80198.75,
#    'open': 80262.58,
#    'volumefrom': 70.55,
#    'volumeto': 5670186.86,
#    'close': 80368.1,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742799600,
#    'high': 80424.44,
#    'low': 80031.61,
#    'open': 80368.1,
#    'volumefrom': 118.43,
#    'volumeto': 9496127.43,
#    'close': 80183.32,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742803200,
#    'high': 80729.02,
#    'low': 80157.04,
#    'open': 80183.32,
#    'volumefrom': 168.62,
#    'volumeto': 13577998.13,
#    'close': 80630.47,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742806800,
#    'high': 80710.4,
#    'low': 80391.9,
#    'open': 80630.47,
#    'volumefrom': 110.66,
#    'volumeto': 8917049.88,
#    'close': 80426.07,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742810400,
#    'high': 81008.91,
#    'low': 80418.72,
#    'open': 80426.07,
#    'volumefrom': 122.43,
#    'volumeto': 9888323.18,
#    'close': 80957,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742814000,
#    'high': 80999.54,
#    'low': 80735.69,
#    'open': 80957,
#    'volumefrom': 96.26,
#    'volumeto': 7784659.38,
#    'close': 80961.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742817600,
#    'high': 80971.6,
#    'low': 80627.91,
#    'open': 80961.8,
#    'volumefrom': 143.2,
#    'volumeto': 11566767.23,
#    'close': 80661.12,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742821200,
#    'high': 81216.51,
#    'low': 80528.21,
#    'open': 80661.12,
#    'volumefrom': 165.59,
#    'volumeto': 13391853.29,
#    'close': 81216.51,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742824800,
#    'high': 82079.27,
#    'low': 81199.23,
#    'open': 81216.51,
#    'volumefrom': 227.67,
#    'volumeto': 18595020.26,
#    'close': 81479.58,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742828400,
#    'high': 81865.65,
#    'low': 81259,
#    'open': 81479.58,
#    'volumefrom': 108.98,
#    'volumeto': 8887753.86,
#    'close': 81853.52,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742832000,
#    'high': 81923.77,
#    'low': 81264.37,
#    'open': 81853.52,
#    'volumefrom': 106.75,
#    'volumeto': 8711610.52,
#    'close': 81589.06,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742835600,
#    'high': 81991.44,
#    'low': 81515.26,
#    'open': 81589.06,
#    'volumefrom': 94.71,
#    'volumeto': 7748104.53,
#    'close': 81986.88,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742839200,
#    'high': 81994.71,
#    'low': 81666.23,
#    'open': 81986.88,
#    'volumefrom': 85.1,
#    'volumeto': 6967277.1,
#    'close': 81902.97,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742842800,
#    'high': 81939.67,
#    'low': 81503.58,
#    'open': 81902.97,
#    'volumefrom': 78.13,
#    'volumeto': 6386396.41,
#    'close': 81752.75,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742846400,
#    'high': 81925.4,
#    'low': 81335.96,
#    'open': 81752.75,
#    'volumefrom': 73.52,
#    'volumeto': 6004940.12,
#    'close': 81357.85,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742850000,
#    'high': 81748.19,
#    'low': 81341.88,
#    'open': 81357.85,
#    'volumefrom': 54.35,
#    'volumeto': 4432588.39,
#    'close': 81605.84,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742853600,
#    'high': 81649.76,
#    'low': 80879.52,
#    'open': 81605.84,
#    'volumefrom': 84.28,
#    'volumeto': 6841218.2,
#    'close': 80966.49,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742857200,
#    'high': 81033.94,
#    'low': 80629.56,
#    'open': 80966.49,
#    'volumefrom': 49.65,
#    'volumeto': 4012856.2,
#    'close': 81011.75,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742860800,
#    'high': 81202.1,
#    'low': 80837.25,
#    'open': 81011.75,
#    'volumefrom': 41.38,
#    'volumeto': 3354196.08,
#    'close': 81135.13,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742864400,
#    'high': 81135.39,
#    'low': 80396.42,
#    'open': 81135.13,
#    'volumefrom': 42.27,
#    'volumeto': 3411241.58,
#    'close': 80630.31,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742868000,
#    'high': 80644.3,
#    'low': 80438.26,
#    'open': 80630.31,
#    'volumefrom': 20.43,
#    'volumeto': 1645359.2,
#    'close': 80473.26,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742871600,
#    'high': 80557.77,
#    'low': 79984.42,
#    'open': 80473.26,
#    'volumefrom': 51.29,
#    'volumeto': 4111483.62,
#    'close': 80113.28,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742875200,
#    'high': 80195.85,
#    'low': 79937.44,
#    'open': 80113.28,
#    'volumefrom': 29.62,
#    'volumeto': 2372289.4,
#    'close': 80112.14,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742878800,
#    'high': 80345.58,
#    'low': 80004.11,
#    'open': 80112.14,
#    'volumefrom': 51.25,
#    'volumeto': 4110589.52,
#    'close': 80258.39,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742882400,
#    'high': 80478.16,
#    'low': 80178.3,
#    'open': 80258.39,
#    'volumefrom': 57.33,
#    'volumeto': 4604462.62,
#    'close': 80183.02,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742886000,
#    'high': 80422.75,
#    'low': 80045.06,
#    'open': 80183.02,
#    'volumefrom': 70,
#    'volumeto': 5613586.43,
#    'close': 80140.75,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742889600,
#    'high': 80412.74,
#    'low': 80136.38,
#    'open': 80140.75,
#    'volumefrom': 72.8,
#    'volumeto': 5845438.63,
#    'close': 80382.04,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742893200,
#    'high': 80875.24,
#    'low': 80311,
#    'open': 80382.04,
#    'volumefrom': 125.07,
#    'volumeto': 10080342.06,
#    'close': 80786.22,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742896800,
#    'high': 80827.14,
#    'low': 80438.7,
#    'open': 80786.22,
#    'volumefrom': 64.28,
#    'volumeto': 5180568.75,
#    'close': 80553.63,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742900400,
#    'high': 80866.89,
#    'low': 80532.53,
#    'open': 80553.63,
#    'volumefrom': 69.08,
#    'volumeto': 5577250.09,
#    'close': 80805.96,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742904000,
#    'high': 80848.02,
#    'low': 80384.51,
#    'open': 80805.96,
#    'volumefrom': 60.36,
#    'volumeto': 4864719.55,
#    'close': 80479.13,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742907600,
#    'high': 81247.86,
#    'low': 80470.12,
#    'open': 80479.13,
#    'volumefrom': 169.87,
#    'volumeto': 13745474.5,
#    'close': 81031.03,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742911200,
#    'high': 81564.07,
#    'low': 80803.15,
#    'open': 81031.03,
#    'volumefrom': 135.89,
#    'volumeto': 11039444.4,
#    'close': 81416.29,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742914800,
#    'high': 81616.35,
#    'low': 81170.68,
#    'open': 81416.29,
#    'volumefrom': 90.54,
#    'volumeto': 7367309.33,
#    'close': 81298.05,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742918400,
#    'high': 81410.46,
#    'low': 81109.91,
#    'open': 81298.05,
#    'volumefrom': 78.16,
#    'volumeto': 6351146.52,
#    'close': 81284.99,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742922000,
#    'high': 81701.49,
#    'low': 81284.27,
#    'open': 81284.99,
#    'volumefrom': 83.67,
#    'volumeto': 6819214.37,
#    'close': 81384.72,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742925600,
#    'high': 81484.91,
#    'low': 81124.82,
#    'open': 81384.72,
#    'volumefrom': 56.47,
#    'volumeto': 4590033.89,
#    'close': 81359.95,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742929200,
#    'high': 81754.56,
#    'low': 81354.47,
#    'open': 81359.95,
#    'volumefrom': 74.83,
#    'volumeto': 6105169.22,
#    'close': 81648.33,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742932800,
#    'high': 82041.43,
#    'low': 81410.37,
#    'open': 81648.33,
#    'volumefrom': 136.65,
#    'volumeto': 11173521.22,
#    'close': 81430.8,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742936400,
#    'high': 81744.97,
#    'low': 81318.79,
#    'open': 81430.8,
#    'volumefrom': 47.2,
#    'volumeto': 3847068.77,
#    'close': 81329.43,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1742940000,
#    'high': 81385.71,
#    'low': 80835.92,
#    'open': 81329.43,
#    'volumefrom': 68.72,
#    'volumeto': 5577467.18,
#    'close': 81118.26,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   ...],
#  1739343600)

# %%
while batch_earliest_date > historical_earliest_date:

    prev_hourly_data, batch_earliest_date = get_hourly_batch_data(batch_earliest_date)
    hourly_data += list(prev_hourly_data)

    print(batch_earliest_date)
# Out:
# 1732143600
# 1724943600
# 1717743600
# 1710543600
# 1703343600
# 1696143600
# 1688943600
# 1681743600
# 1674543600
# 1667343600
# 1660143600
# 1652943600
# 1645743600
# 1638543600
# 1631343600
# 1624143600
# 1616943600
# 1609743600
# 1602543600
# 1595343600
# 1588143600
# 1580943600
# 1573743600
# 1566543600
# 1559343600
# 1552143600
# 1544943600
# 1537743600
# 1530543600
# 1523343600
# 1516143600
# 1508943600
# 1501743600
# 1494543600
# 1487343600
# 1480143600
# 1472943600
# 1465743600
# 1458543600
# 1451343600
# 1444143600
# 1436943600
# 1429743600
# 1422543600
# 1415343600
# 1408143600
# 1400943600
# 1393743600
# 1386543600
# 1379343600
# 1372143600
# 1364943600
# 1357743600
# 1350543600
# 1343343600
# 1336143600
# 1328943600
# 1321743600
# 1314543600
# 1307343600

# %%
hourly_df = pd.json_normalize(hourly_data)

# %%
hourly_df
# Out:
#               time       high        low       open  volumefrom    volumeto  \
# 0       1739343600  92810.040  92513.660  92536.280       84.70  7842919.38
# 1       1739347200  92994.990  92610.110  92615.790       56.13  5207567.66
# 2       1739350800  92959.120  92633.520  92947.710       69.38  6434326.89
# 3       1739354400  92775.400  92501.710  92722.290       46.74  4330883.15
# 4       1739358000  92862.330  92532.970  92533.050       66.94  6204274.02
# ...            ...        ...        ...        ...         ...         ...
# 122056  1314529200      6.145      6.145      6.145        0.00        0.00
# 122057  1314532800      6.145      6.145      6.145        0.00        0.00
# 122058  1314536400      6.145      6.145      6.145        0.00        0.00
# 122059  1314540000      6.145      6.145      6.145        0.00        0.00
# 122060  1314543600      6.145      6.145      6.145        0.00        0.00
#
#             close conversionType conversionSymbol
# 0       92615.790         direct
# 1       92947.710         direct
# 2       92722.290         direct
# 3       92533.050         direct
# 4       92647.660         direct
# ...           ...            ...              ...
# 122056      6.145         direct
# 122057      6.145         direct
# 122058      6.145         direct
# 122059      6.145         direct
# 122060      6.145         direct
#
# [122061 rows x 9 columns]

# %%
hourly_df["time"] = hourly_df["time"].apply(lambda time: datetime.fromtimestamp(time))
hourly_df.drop(columns=["conversionType", "conversionSymbol"], inplace=True)

# %%
hourly_df.sort_values(by=["time"], ascending=True, inplace=True)

# %%
hourly_df.reset_index(drop=True, inplace=True)
hourly_df
# Out:
#                       time      high       low      open  volumefrom  \
# 0      2011-06-06 09:00:00      0.00      0.00      0.00        0.00
# 1      2011-06-06 10:00:00      0.00      0.00      0.00        0.00
# 2      2011-06-06 11:00:00      0.00      0.00      0.00        0.00
# 3      2011-06-06 12:00:00      0.00      0.00      0.00        0.00
# 4      2011-06-06 13:00:00      0.00      0.00      0.00        0.00
# ...                    ...       ...       ...       ...         ...
# 122056 2025-05-06 13:00:00  83076.83  82756.62  82975.02       52.45
# 122057 2025-05-06 14:00:00  82959.73  82785.46  82857.12       46.62
# 122058 2025-05-06 15:00:00  82879.31  82281.16  82870.26      139.24
# 122059 2025-05-06 16:00:00  83433.43  82481.40  82490.53      119.36
# 122060 2025-05-06 17:00:00  83494.68  82998.59  83033.24       39.29
#
#            volumeto     close
# 0              0.00      0.00
# 1              0.00      0.00
# 2              0.00      0.00
# 3              0.00      0.00
# 4              0.00      0.00
# ...             ...       ...
# 122056   4350319.08  82857.12
# 122057   3864315.77  82870.26
# 122058  11503479.44  82490.53
# 122059   9911093.23  83033.24
# 122060   3271183.76  83481.33
#
# [122061 rows x 7 columns]

# %%
def process_df(data: list) -> pd.DataFrame:

    # Convert list of json into a single DataFrame
    df = pd.json_normalize(data)

    # Convert date format: from integers (i.e timestamps) to dates
    df["time"] = df["time"].apply(lambda time: datetime.fromtimestamp(time))
    
    df.drop(columns=["conversionType", "conversionSymbol"], inplace=True)

    # Sort DataFrame from earliest to latest date and reset index
    df.sort_values(by=["time"], ascending=True, inplace=True)
    df.reset_index(drop=True, inplace=True)

    return df

# %%
hourly_df.to_csv("btc_hourly_data.csv")
